# %%
import requests
import json

def save_image(url, FileName) :
    img_response = requests.get(url)
    
    if img_response.status_code == 200 :
        #print(img_response.content)
        print("=" * 30 + "[이미지 저장]" + "=" * 30)
        file = "./output/" + FileName
        with open(file, "wb") as fp :
            fp.write(img_response.content)

REST_API_KEY = 'd676a99a6401e791249d4e7e0b52c4fa'
QUERY = '노라조'

url = 'https://dapi.kakao.com/v2/search/image'
headers = {"Authorization" : f"KakaoAK {REST_API_KEY}"}
data = {"query" : f"{QUERY}"}

response = requests.post(url, headers=headers, data=data)
if response.status_code != 200 :
    print("error !!! because ", response.json())
else :
    count = 0
    for image_info in response.json()['documents'] :
        print(f"[{count}th] image_url =", image_info['image_url'])
        count = count + 1
        file_name = f"{QUERY}_%d.jpg" %(count)
        save_image(image_info['image_url'], file_name)
# Out:
# [0th] image_url = http://cfile190.uf.daum.net/image/1213BE1C4990DFF766F6B6
# ==============================[이미지 저장]==============================
# [1th] image_url = https://postfiles.pstatic.net/20101121_120/navasura_1290318886290WwP5m_JPEG/%B3%EB%B6%F3%C1%B6_3.jpg?type=w2
# ==============================[이미지 저장]==============================
# [2th] image_url = https://t1.daumcdn.net/news/202010/03/ilgansports/20201003094033788cbki.jpg
# ==============================[이미지 저장]==============================
# [3th] image_url = http://t1.daumcdn.net/cafeattach/Uzlo/b179c51af76d077cc1472d3ca7c107989320f4df
# ==============================[이미지 저장]==============================
# [4th] image_url = https://blog.kakaocdn.net/dn/0pGGF/btsNHgAUNOb/Q84nscik9iX33iIiHEUfVk/img.png
# ==============================[이미지 저장]==============================
# [5th] image_url = http://cfile294.uf.daum.net/image/117AA8114C7A70EBE7F928
# ==============================[이미지 저장]==============================
# [6th] image_url = https://t1.daumcdn.net/news/201901/14/sportskhan/20190114133757131vlwh.jpg
# ==============================[이미지 저장]==============================
# [7th] image_url = https://t1.daumcdn.net/news/201809/19/seoul/20180919033630449aein.jpg
# ==============================[이미지 저장]==============================
# [8th] image_url = http://t1.daumcdn.net/news/201702/09/10asia/20170209091942791nbxg.jpg
# ==============================[이미지 저장]==============================
# [9th] image_url = http://t1.daumcdn.net/news/201111/22/ned/20111122101820831.jpg
# ==============================[이미지 저장]==============================
# [10th] image_url = http://cfile274.uf.daum.net/image/142500304C4CCCBD76B594
# ==============================[이미지 저장]==============================
# [11th] image_url = https://t1.daumcdn.net/news/202109/02/tvdaily/20210902114915830iqxy.jpg
# ==============================[이미지 저장]==============================
# [12th] image_url = https://archivenew.vop.co.kr/images/90952a5d266e2222a78d4eb07938162f/2019-08/marked/16043428_634523523.jpg
# ==============================[이미지 저장]==============================
# [13th] image_url = https://t1.daumcdn.net/news/202507/01/joongang/20250701205744641eknk.jpg
# ==============================[이미지 저장]==============================
# [14th] image_url = https://postfiles.pstatic.net/20131103_126/hanmesan68_1383474204376ee9Dt_JPEG/%C0%CE%B1%E2%BF%AC%BF%B9%C0%CE%BD%BA%C5%B8%BB%E7%C1%F8_%B3%EB%B6%F3%C1%B6_%BE%C7%C7%C3%BF%A1_%B4%EB%C3%B3%C7%CF%B4%C2_%B1%D7%B5%E9%C0%C7_%C0%DA%BC%BC1.jpg?type=w1
# ==============================[이미지 저장]==============================
# [15th] image_url = http://t1.daumcdn.net/news/201404/07/segye/20140407213105097.jpg
# ==============================[이미지 저장]==============================
# [16th] image_url = http://pds25.cafe.daum.net/download.php?grpid=100lq&fldid=5QZs&dataid=49&fileid=1&regdt=20050829113838&disk=31&grpcode=norazofan&dncnt=N&.jpg
# [17th] image_url = http://cfile270.uf.daum.net/image/115B91434FA4F9B6193F6B
# ==============================[이미지 저장]==============================
# [18th] image_url = https://blog.kakaocdn.net/dn/cQyJHr/btsJqjCCAO3/8DkqBEFaViSDgCswk6lqA1/img.webp
# ==============================[이미지 저장]==============================
# [19th] image_url = http://www.cstimes.com/news/photo/202012/441241_341071_3252.jpg
# ==============================[이미지 저장]==============================
# [20th] image_url = http://t1.daumcdn.net/news/201111/18/akn/20111118101712789.jpg
# ==============================[이미지 저장]==============================
# [21th] image_url = https://t1.daumcdn.net/cfile/153DF7264CAAD0F818
# ==============================[이미지 저장]==============================
# [22th] image_url = http://t1.daumcdn.net/news/200903/20/segye/20090320205806.604.0.jpg
# ==============================[이미지 저장]==============================
# [23th] image_url = https://blog.kakaocdn.net/dn/cGJr2E/btsOcFmX0pm/W0775HGxlQgeFRJqdcEnyK/img.jpg
# ==============================[이미지 저장]==============================
# [24th] image_url = https://t1.daumcdn.net/news/202201/14/tvdaily/20220114124008279tcpr.jpg
# ==============================[이미지 저장]==============================
# [25th] image_url = http://t1.daumcdn.net/news/200709/17/starnews/20070917165803.319.1.jpg
# ==============================[이미지 저장]==============================
# [26th] image_url = http://pds39.cafe.daum.net/image/28/cafe/2007/06/11/15/01/466ce52abc6c0
# ==============================[이미지 저장]==============================
# [27th] image_url = https://t1.daumcdn.net/news/202508/03/JTBC/20250803083857282krsd.jpg
# ==============================[이미지 저장]==============================
# [28th] image_url = http://pds107.cafe.daum.net/image/16/cafe/2008/12/12/16/30/49421305a9f05
# ==============================[이미지 저장]==============================
# [29th] image_url = https://blog.kakaocdn.net/dn/lo6Qp/btsIRo4vPxQ/lB0PeIVY0YGkYuaIoZPdKk/img.png
# ==============================[이미지 저장]==============================
# [30th] image_url = http://i2.media.daumcdn.net/svc/image/U03/news/201507/12/newsone/20150712080237758dgme.jpg
# ==============================[이미지 저장]==============================
# [31th] image_url = http://t1.daumcdn.net/news/200703/24/osen/20070324113511.506.1.jpg
# ==============================[이미지 저장]==============================
# [32th] image_url = https://t1.daumcdn.net/news/202204/15/tvdaily/20220415071919735shww.jpg
# ==============================[이미지 저장]==============================
# [33th] image_url = http://t1.daumcdn.net/cafeattach/Uzlo/39e7e9e89ae28b251a3e7f65b623267547fd520c
# ==============================[이미지 저장]==============================
# [34th] image_url = https://t1.daumcdn.net/news/202104/19/tvdaily/20210419130809667musg.jpg
# ==============================[이미지 저장]==============================
# [35th] image_url = http://t1.daumcdn.net/cafeattach/1WjuI/6caedb091051ea2ea5020dd5f6bb031fb811deb1
# ==============================[이미지 저장]==============================
# [36th] image_url = http://t1.daumcdn.net/news/201111/30/sportschosun/20111130083412049.jpg
# ==============================[이미지 저장]==============================
# [37th] image_url = http://t1.daumcdn.net/news/201007/20/ned/20100720113218444.jpeg
# ==============================[이미지 저장]==============================
# [38th] image_url = https://postfiles.pstatic.net/20120606_288/kyuhee08_1338959838976eE7eh_JPEG/%B3%EB%B6%F3%C1%E0_00005.jpg?type=w2
# ==============================[이미지 저장]==============================
# [39th] image_url = http://t1.daumcdn.net/news/201109/29/sportsdonga/20110929071608990.jpg
# ==============================[이미지 저장]==============================
# [40th] image_url = http://cfile270.uf.daum.net/image/121D98174990E59F8D0C4F
# ==============================[이미지 저장]==============================
# [41th] image_url = https://postfiles.pstatic.net/20141028_8/aowlr0529_1414482396240gGR7v_JPEG/%B3%EB%B6%F3%C1%B6.jpg?type=w3
# ==============================[이미지 저장]==============================
# [42th] image_url = https://t1.daumcdn.net/cfile/tistory/99B886425BDC6CCB38
# ==============================[이미지 저장]==============================
# [43th] image_url = https://blog.kakaocdn.net/dn/4tnIt/btqIRMyNhx8/NHjqjMKW4vDZG61DwKaBHk/img.jpg
# ==============================[이미지 저장]==============================
# [44th] image_url = https://postfiles.pstatic.net/20111130_197/yeilsound_1322615246641memef_JPEG/%B3%EB%B6%F3%C1%B6_%B0%A1%C0%CC%BE%C65.jpg?type=w2
# ==============================[이미지 저장]==============================
# [45th] image_url = https://postfiles.pstatic.net/20090810_216/todsea2_1249887892122wilmi_jpg/dsc00088_todsea2.jpg?type=w2
# ==============================[이미지 저장]==============================
# [46th] image_url = http://t1.daumcdn.net/news/201208/07/sportsdonga/20120807164703324.jpg
# ==============================[이미지 저장]==============================
# [47th] image_url = http://thumb.mtstarnews.com/06/2011/12/2011123119395333762_1.jpg?time=052310
# ==============================[이미지 저장]==============================
# [48th] image_url = http://cfile296.uf.daum.net/image/19531D434FA4F9B6208486
# ==============================[이미지 저장]==============================
# [49th] image_url = https://postfiles.pstatic.net/20111113_241/kraius80_13211100449438jaHK_JPEG/14.jpg?type=w2
# ==============================[이미지 저장]==============================
# [50th] image_url = https://search2.kakaocdn.net/argon/0x200_85_hr/2VYppkjRMKH
# ==============================[이미지 저장]==============================
# [51th] image_url = https://t1.daumcdn.net/news/201808/21/poctan/20180821145604073fofv.jpg
# ==============================[이미지 저장]==============================
# [52th] image_url = https://t1.daumcdn.net/news/201904/12/seoul/20190412033633559omie.jpg
# ==============================[이미지 저장]==============================
# [53th] image_url = https://t1.daumcdn.net/news/201808/21/Edaily/20180821184545828vkjf.jpg
# ==============================[이미지 저장]==============================
# [54th] image_url = https://blog.kakaocdn.net/dn/BIzXR/btrfFGf8sFp/3I1VdwenZxLzV24ZVgCkO1/img.jpg
# ==============================[이미지 저장]==============================
# [55th] image_url = http://t1.daumcdn.net/news/201307/13/fnnewsi/20130713213110132.jpg
# ==============================[이미지 저장]==============================
# [56th] image_url = https://t1.daumcdn.net/cfile/tistory/99ABA13E5C2970B80E
# ==============================[이미지 저장]==============================
# [57th] image_url = http://www.stardailynews.co.kr/news/thumbnail/201908/252101_286560_4238_v150.jpg
# ==============================[이미지 저장]==============================
# [58th] image_url = https://t1.daumcdn.net/news/201902/23/starnews/20190223134000068ntrc.jpg
# ==============================[이미지 저장]==============================
# [59th] image_url = http://cfile251.uf.daum.net/image/1441D8174BE4065475EB32
# ==============================[이미지 저장]==============================
# [60th] image_url = https://t1.daumcdn.net/news/202104/15/mksports/20210415091935865zxng.jpg
# ==============================[이미지 저장]==============================
# [61th] image_url = https://postfiles.pstatic.net/MjAyNTA5MDlfMTMx/MDAxNzU3NDE5NDUyNzEx.S-AWl0NOfvXDRHMGyXYPlNJ5FhW5lYM-9qrcUtg4IDMg.jXOYLUu_2maeefZ3Cinjc3rNd7tSh7lO671b3DWkgo4g.JPEG/201904091630292067_d.jpg?type=w966
# ==============================[이미지 저장]==============================
# [62th] image_url = http://t1.daumcdn.net/news/201702/09/nocut/20170209102303330fweh.jpg
# ==============================[이미지 저장]==============================
# [63th] image_url = https://t1.daumcdn.net/news/201901/14/tvdaily/20190114162705622xddk.jpg
# ==============================[이미지 저장]==============================
# [64th] image_url = http://kstatic.inven.co.kr/upload/2018/08/22/bbs/i15782111062.jpg
# ==============================[이미지 저장]==============================
# [65th] image_url = http://t1.daumcdn.net/news/201208/07/fnnewsi/20120807140419308.jpg
# ==============================[이미지 저장]==============================
# [66th] image_url = https://t1.daumcdn.net/news/202507/30/sportskhan/20250730083005603nfin.jpg
# ==============================[이미지 저장]==============================
# [67th] image_url = http://t1.daumcdn.net/news/201111/08/spohankook/20111108060354436.jpg
# ==============================[이미지 저장]==============================
# [68th] image_url = https://postfiles.pstatic.net/MjAxNzA0MjZfNTEg/MDAxNDkzMTg5NTczODE4.wN64x27K7zFr4gZfq6cedErVPMe-xzXlfbZSWRootjEg.fhrD_ahFjhhoWsGcvPLokKFge64ox2488g9xe4WwfNUg.JPEG.waterlily1982/%EB%85%B8%EB%9D%BC%EC%A1%B03.jpg?type=w1
# ==============================[이미지 저장]==============================
# [69th] image_url = https://t1.daumcdn.net/news/201809/04/10asia/20180904112030575dtfn.jpg
# ==============================[이미지 저장]==============================
# [70th] image_url = http://cfile270.uf.daum.net/image/207B30244ADFF2181087E6
# ==============================[이미지 저장]==============================
# [71th] image_url = http://img2.daumcdn.net/thumb/R658x0.q70/?fname=http://t1.daumcdn.net/news/200901/29/hankooki/20090129072404977.jpeg
# ==============================[이미지 저장]==============================
# [72th] image_url = https://t1.daumcdn.net/news/201808/13/Edaily/20180813093901429nebz.jpg
# ==============================[이미지 저장]==============================
# [73th] image_url = https://t1.daumcdn.net/news/201907/19/mksports/20190719125103283kfrb.jpg
# ==============================[이미지 저장]==============================
# [74th] image_url = http://t1.daumcdn.net/news/200706/20/osen/20070620190511.982.0.jpg
# ==============================[이미지 저장]==============================
# [75th] image_url = http://t1.daumcdn.net/news/201311/15/newsen/20131115200805467.jpg
# ==============================[이미지 저장]==============================
# [76th] image_url = http://i2.media.daumcdn.net/svc/image/U03/news/201507/12/newsone/20150712080227697cnzf.jpg
# ==============================[이미지 저장]==============================
# [77th] image_url = https://postfiles.pstatic.net/20120504_243/moneycal_1336108925396RxfJx_JPEG/%B3%EB%B6%F3%C1%B6_%BF%A9%C0%DA%BB%E7%B6%F7_2.png?type=w2
# ==============================[이미지 저장]==============================
# [78th] image_url = https://dispatch.cdnser.be/cms-content/uploads/2019/08/16/fff39c72-7379-4315-ba17-fe16da2dcb19.jpg
# ==============================[이미지 저장]==============================
# [79th] image_url = https://t1.daumcdn.net/news/201808/20/seoul/20180820152603607uotf.jpg
# ==============================[이미지 저장]==============================
